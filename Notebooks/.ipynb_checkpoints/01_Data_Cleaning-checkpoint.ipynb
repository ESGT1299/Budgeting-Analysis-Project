# %%
! pip install pandas numpy sqlalchemy psycopg2 openpyxl jupyter matplotlib seaborn statsmodels
# Out:
# Collecting pandas
#   Downloading pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting numpy
#   Downloading numpy-2.2.4-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting sqlalchemy
#   Downloading sqlalchemy-2.0.39-cp312-cp312-win_amd64.whl.metadata (9.9 kB)
# Collecting psycopg2
#   Downloading psycopg2-2.9.10-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# Collecting openpyxl
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting jupyter
#   Using cached jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.10.1-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting statsmodels
#   Downloading statsmodels-0.14.4-cp312-cp312-win_amd64.whl.metadata (9.5 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting greenlet!=0.4.17 (from sqlalchemy)
#   Downloading greenlet-3.1.1-cp312-cp312-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from sqlalchemy) (4.12.2)
# Collecting et-xmlfile (from openpyxl)
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: notebook in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from jupyter) (7.3.2)
# Collecting jupyter-console (from jupyter)
#   Using cached jupyter_console-6.6.3-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: nbconvert in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from jupyter) (7.16.6)
# Requirement already satisfied: ipykernel in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from jupyter) (6.29.5)
# Collecting ipywidgets (from jupyter)
#   Using cached ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: jupyterlab in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from jupyter) (4.3.4)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.1-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.56.0-cp312-cp312-win_amd64.whl.metadata (103 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.8-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from matplotlib) (24.2)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.1.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Using cached pyparsing-3.2.1-py3-none-any.whl.metadata (5.0 kB)
# Collecting scipy!=1.9.2,>=1.8 (from statsmodels)
#   Downloading scipy-1.15.2-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting patsy>=0.5.6 (from statsmodels)
#   Using cached patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: six>=1.5 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from ipykernel->jupyter) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from ipykernel->jupyter) (1.8.11)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from ipykernel->jupyter) (8.30.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from ipykernel->jupyter) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from ipykernel->jupyter) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from ipykernel->jupyter) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: psutil in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from ipykernel->jupyter) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from ipykernel->jupyter) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from ipykernel->jupyter) (6.4.2)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from ipykernel->jupyter) (5.14.3)
# Collecting widgetsnbextension~=4.0.12 (from ipywidgets->jupyter)
#   Using cached widgetsnbextension-4.0.13-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.12 (from ipywidgets->jupyter)
#   Using cached jupyterlab_widgets-3.0.13-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from jupyter-console->jupyter) (3.0.43)
# Requirement already satisfied: pygments in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from jupyter-console->jupyter) (2.15.1)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from jupyterlab->jupyter) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from jupyterlab->jupyter) (0.27.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from jupyterlab->jupyter) (3.1.6)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from jupyterlab->jupyter) (2.2.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from jupyterlab->jupyter) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from jupyterlab->jupyter) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from jupyterlab->jupyter) (0.2.4)
# Requirement already satisfied: setuptools>=40.8.0 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from jupyterlab->jupyter) (75.8.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from nbconvert->jupyter) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from nbconvert->jupyter) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from nbconvert->jupyter) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from nbconvert->jupyter) (0.10.2)
# Requirement already satisfied: nbformat>=5.7 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from nbconvert->jupyter) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from nbconvert->jupyter) (1.5.0)
# Requirement already satisfied: webencodings in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (1.4.0)
# Requirement already satisfied: anyio in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (4.6.2)
# Requirement already satisfied: certifi in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (1.0.2)
# Requirement already satisfied: idna in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (3.7)
# Requirement already satisfied: sniffio in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter) (0.14.0)
# Requirement already satisfied: decorator in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.19.2)
# Requirement already satisfied: stack-data in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.2.0)
# Requirement already satisfied: colorama in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.4.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (308)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.4.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.21.0)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.0.15)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (4.23.0)
# Requirement already satisfied: requests>=2.31 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.32.3)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter) (2.20.0)
# Requirement already satisfied: wcwidth in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter) (0.2.5)
# Requirement already satisfied: soupsieve>1.2 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.5)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.22.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.2.1)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (6.0.2)
# Requirement already satisfied: rfc3339-validator in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.3.0)
# Requirement already satisfied: executing in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.2.2)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter)
#   Using cached fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter)
#   Using cached isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting jsonpointer>1.13 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter)
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter)
#   Using cached uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=24.6.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter)
#   Using cached webcolors-24.11.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\antho\.conda\envs\budgeting_project\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.21)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter)
#   Using cached arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting types-python-dateutil>=2.8.10 (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter)
#   Using cached types_python_dateutil-2.9.0.20241206-py3-none-any.whl.metadata (2.1 kB)
# Downloading pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    -------------------------- ------------- 7.6/11.5 MB 39.0 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 31.2 MB/s eta 0:00:00
# Downloading numpy-2.2.4-cp312-cp312-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ----------------------------- ---------- 9.2/12.6 MB 43.9 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 31.7 MB/s eta 0:00:00
# Downloading sqlalchemy-2.0.39-cp312-cp312-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 39.2 MB/s eta 0:00:00
# Downloading psycopg2-2.9.10-cp312-cp312-win_amd64.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 28.2 MB/s eta 0:00:00
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Downloading matplotlib-3.10.1-cp312-cp312-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------  7.9/8.1 MB 44.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 35.6 MB/s eta 0:00:00
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading statsmodels-0.14.4-cp312-cp312-win_amd64.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    -------------------------------------- - 9.4/9.8 MB 45.2 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 34.0 MB/s eta 0:00:00
# Downloading contourpy-1.3.1-cp312-cp312-win_amd64.whl (220 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.56.0-cp312-cp312-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 30.6 MB/s eta 0:00:00
# Downloading greenlet-3.1.1-cp312-cp312-win_amd64.whl (299 kB)
# Downloading kiwisolver-1.4.8-cp312-cp312-win_amd64.whl (71 kB)
# Using cached patsy-1.0.1-py2.py3-none-any.whl (232 kB)
# Downloading pillow-11.1.0-cp312-cp312-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 2.6/2.6 MB 30.3 MB/s eta 0:00:00
# Using cached pyparsing-3.2.1-py3-none-any.whl (107 kB)
# Using cached pytz-2025.1-py2.py3-none-any.whl (507 kB)
# Downloading scipy-1.15.2-cp312-cp312-win_amd64.whl (40.9 MB)
#    ---------------------------------------- 0.0/40.9 MB ? eta -:--:--
#    --------- ------------------------------ 9.7/40.9 MB 46.5 MB/s eta 0:00:01
#    ------------------ --------------------- 19.1/40.9 MB 46.5 MB/s eta 0:00:01
#    -------------------------- ------------- 27.3/40.9 MB 44.3 MB/s eta 0:00:01
#    ------------------------------------ --- 37.7/40.9 MB 45.3 MB/s eta 0:00:01
#    ---------------------------------------  40.9/40.9 MB 45.7 MB/s eta 0:00:01
#    ---------------------------------------  40.9/40.9 MB 45.7 MB/s eta 0:00:01
#    ---------------------------------------- 40.9/40.9 MB 30.6 MB/s eta 0:00:00
# Using cached tzdata-2025.1-py2.py3-none-any.whl (346 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Using cached ipywidgets-8.1.5-py3-none-any.whl (139 kB)
# Using cached jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Using cached jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
# Using cached widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
# Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Using cached webcolors-24.11.1-py3-none-any.whl (14 kB)
# Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Using cached uri_template-1.3.0-py3-none-any.whl (11 kB)
# Using cached arrow-1.3.0-py3-none-any.whl (66 kB)
# Using cached types_python_dateutil-2.9.0.20241206-py3-none-any.whl (14 kB)
# Installing collected packages: pytz, widgetsnbextension, webcolors, uri-template, tzdata, types-python-dateutil, pyparsing, psycopg2, pillow, numpy, kiwisolver, jupyterlab-widgets, jsonpointer, greenlet, fqdn, fonttools, et-xmlfile, cycler, sqlalchemy, scipy, patsy, pandas, openpyxl, contourpy, arrow, statsmodels, matplotlib, isoduration, seaborn, ipywidgets, jupyter-console, jupyter
# Successfully installed arrow-1.3.0 contourpy-1.3.1 cycler-0.12.1 et-xmlfile-2.0.0 fonttools-4.56.0 fqdn-1.5.1 greenlet-3.1.1 ipywidgets-8.1.5 isoduration-20.11.0 jsonpointer-3.0.0 jupyter-1.1.1 jupyter-console-6.6.3 jupyterlab-widgets-3.0.13 kiwisolver-1.4.8 matplotlib-3.10.1 numpy-2.2.4 openpyxl-3.1.5 pandas-2.2.3 patsy-1.0.1 pillow-11.1.0 psycopg2-2.9.10 pyparsing-3.2.1 pytz-2025.1 scipy-1.15.2 seaborn-0.13.2 sqlalchemy-2.0.39 statsmodels-0.14.4 types-python-dateutil-2.9.0.20241206 tzdata-2025.1 uri-template-1.3.0 webcolors-24.11.1 widgetsnbextension-4.0.13

# %%
import pandas as pd
from sqlalchemy import create_engine

# --- Configuration ---
db_username = "postgres"
db_password = "ESgt09601698."  # Replace with your password
db_host = "localhost"
db_port = "5432"
db_name = "budgeting_db"

# Create SQLAlchemy Engine
engine = create_engine(f"postgresql://{db_username}:{db_password}@{db_host}:{db_port}/{db_name}")

# --- Data Ingestion ---
df = pd.read_csv("data/bank.csv")
print("Original Columns:", df.columns)

# --- Data Cleaning ---
# Standardize column names
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

# Retain necessary columns
df = df[['date', 'transaction_details', 'withdrawal_amt', 'deposit_amt', 'balance_amt']]

# Convert date to datetime and clean numeric columns (remove commas, convert to float)
df['date'] = pd.to_datetime(df['date'], errors='coerce')
for col in ['withdrawal_amt', 'deposit_amt', 'balance_amt']:
    df[col] = df[col].astype(str).str.replace(',', '').astype(float).fillna(0)

# --- Enhanced Categorization ---
def categorize_transaction(detail, withdrawal, deposit):
    """
    Categorize transactions based on details and amount.
    
    Rules (refined via EDA):
    - If details indicate incoming transfers ("trf from" or "trf frm"), label as "Incoming Transfer".
    - If details suggest internal movements ("internal fund" or "fdrl"), label as "Internal Fund Transfer".
    - If details mention "remi", consider it a "Remittance Fee".
    - If details mention "gibl", label it as "Bank Charges".
    - Otherwise, use amount information:
         * deposit > 0 and withdrawal == 0 → "Deposit"
         * withdrawal > 0 and deposit == 0 → "Withdrawal"
         * Else → "Other"
    """
    detail_lower = str(detail).lower()
    
    if "trf from" in detail_lower or "trf frm" in detail_lower:
        return "Incoming Transfer"
    elif "internal fund" in detail_lower or "fdrl" in detail_lower:
        return "Internal Fund Transfer"
    elif "remi" in detail_lower:
        return "Remittance Fee"
    elif "gibl" in detail_lower:
        return "Bank Charges"
    else:
        if deposit > 0 and withdrawal == 0:
            return "Deposit"
        elif withdrawal > 0 and deposit == 0:
            return "Withdrawal"
        else:
            return "Other"

# Apply categorization row by row
df['category'] = df.apply(lambda row: categorize_transaction(row['transaction_details'],
                                                               row['withdrawal_amt'],
                                                               row['deposit_amt']),
                          axis=1)

print("Sample Data After Categorization:")
print(df.head(15))

# --- Save Cleaned Data ---
df.to_csv("data/cleaned_bank.csv", index=False)
print("✅ Cleaned data saved to 'data/cleaned_bank.csv'")

# --- Insert Cleaned Data into PostgreSQL (Replace Table) ---
df.to_sql('transactions', engine, if_exists='replace', index=False)
print("✅ Data successfully inserted into PostgreSQL (table replaced)!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 15
#      12 engine = create_engine(f"postgresql://{db_username}:{db_password}@{db_host}:{db_port}/{db_name}")
#      14 # --- Data Ingestion ---
# ---> 15 df = pd.read_csv("C:/Users/Antho/Documents/finance_project/Budgeting%20Analysis/data/bank.csv")
#      16 print("Original Columns:", df.columns)
#      18 # --- Data Cleaning ---
#      19 # Standardize column names
#
# File ~\.conda\envs\budgeting_project\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\.conda\envs\budgeting_project\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\.conda\envs\budgeting_project\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\.conda\envs\budgeting_project\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\.conda\envs\budgeting_project\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/Antho/Documents/finance_project/Budgeting%20Analysis/data/bank.csv'
